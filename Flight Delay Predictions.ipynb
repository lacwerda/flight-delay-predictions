# %%
import numpy as np
import pandas as pd
import seaborn as sb

# %%
flights_file = pd.read_csv('archive\\flights.csv')
# Out:
# C:\Users\011708631\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
flights_file.head(20)
# Out:
#     YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0   2015      1    1            4      AS             98      N407AS
# 1   2015      1    1            4      AA           2336      N3KUAA
# 2   2015      1    1            4      US            840      N171US
# 3   2015      1    1            4      AA            258      N3HYAA
# 4   2015      1    1            4      AS            135      N527AS
# 5   2015      1    1            4      DL            806      N3730B
# 6   2015      1    1            4      NK            612      N635NK
# 7   2015      1    1            4      US           2013      N584UW
# 8   2015      1    1            4      AA           1112      N3LAAA
# 9   2015      1    1            4      DL           1173      N826DN
# 10  2015      1    1            4      DL           2336      N958DN
# 11  2015      1    1            4      AA           1674      N853AA
# 12  2015      1    1            4      DL           1434      N547US
# ...

# %%
flights_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5819079 entries, 0 to 5819078
# Data columns (total 31 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   YEAR                 int64
#  1   MONTH                int64
#  2   DAY                  int64
#  3   DAY_OF_WEEK          int64
#  4   AIRLINE              object
#  5   FLIGHT_NUMBER        int64
#  6   TAIL_NUMBER          object
#  7   ORIGIN_AIRPORT       object
#  8   DESTINATION_AIRPORT  object
#  9   SCHEDULED_DEPARTURE  int64
#  10  DEPARTURE_TIME       float64
#  11  DEPARTURE_DELAY      float64
#  12  TAXI_OUT             float64
#  13  WHEELS_OFF           float64
#  14  SCHEDULED_TIME       float64
#  15  ELAPSED_TIME         float64
#  16  AIR_TIME             float64
#  17  DISTANCE             int64
#  18  WHEELS_ON            float64
#  19  TAXI_IN              float64
#  20  SCHEDULED_ARRIVAL    int64
#  21  ARRIVAL_TIME         float64
#  22  ARRIVAL_DELAY        float64
# ...

# %%
flights_file.shape
# Out:
# (5819079, 31)

# %%
flights = flights_file[0:200000]

# %%
airports = pd.read_csv('archive\\airports.csv')

# %%
airports.head()
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919
# 3  45.44906  -98.42183
# 4  31.53552  -84.19447

# %%
airlines = pd.read_csv('archive\\airlines.csv')

# %%
airlines.head()
# Out:
#   IATA_CODE                 AIRLINE
# 0        UA   United Air Lines Inc.
# 1        AA  American Airlines Inc.
# 2        US         US Airways Inc.
# 3        F9  Frontier Airlines Inc.
# 4        B6         JetBlue Airways

# %%
airlines.shape
# Out:
# (14, 2)

# %%
airports.shape
# Out:
# (322, 7)

# %%
flights.value_counts('DIVERTED')
# Out:
# DIVERTED
# 0    199478
# 1       522
# dtype: int64

# %%
sb.jointplot(data=flights, x="SCHEDULED_ARRIVAL", y="ARRIVAL_TIME")

# %%
corr = flights.corr(method='pearson')

# %%
sb.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
 # NUMBER OF NANS IN EACH COLUMN
cols = list(corr.columns)

for i in cols:
    k = corr[f'{i}']
    print(f'{i}: {k.isnull().sum()}')
# Out:
# YEAR: 26
# MONTH: 26
# DAY: 2
# DAY_OF_WEEK: 2
# FLIGHT_NUMBER: 2
# SCHEDULED_DEPARTURE: 2
# DEPARTURE_TIME: 2
# DEPARTURE_DELAY: 2
# TAXI_OUT: 2
# WHEELS_OFF: 2
# SCHEDULED_TIME: 2
# ELAPSED_TIME: 4
# AIR_TIME: 4
# DISTANCE: 2
# WHEELS_ON: 3
# TAXI_IN: 3
# SCHEDULED_ARRIVAL: 2
# ARRIVAL_TIME: 3
# ARRIVAL_DELAY: 4
# DIVERTED: 10
# CANCELLED: 13
# AIR_SYSTEM_DELAY: 4
# SECURITY_DELAY: 4
# AIRLINE_DELAY: 4
# LATE_AIRCRAFT_DELAY: 4
# WEATHER_DELAY: 4

# %%
corr.shape
# Out:
# (26, 26)

# %%
flights=flights.drop(['YEAR','FLIGHT_NUMBER','AIRLINE','DISTANCE','TAIL_NUMBER','TAXI_OUT',
                                              'SCHEDULED_TIME','DEPARTURE_TIME','WHEELS_OFF','ELAPSED_TIME',
                                              'AIR_TIME','WHEELS_ON','DAY_OF_WEEK','TAXI_IN','CANCELLATION_REASON'],
                                             axis=1)
